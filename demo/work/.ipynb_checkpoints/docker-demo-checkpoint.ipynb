# %% [markdown]
# ### Start a spark session

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-sharing-spark_2.12:3.3.0") \
    .getOrCreate()

# %% [markdown]
# ### List Tables
# Use the provided config

# %%
import delta_sharing
config = "config.share"
client = delta_sharing.SharingClient(config)
client.list_all_tables()
# Out:
# [Table(name='ev3_device_data', share='start_hack_2025', schema='start_hack_2025'),
#  Table(name='cc_api_logs', share='start_hack_2025', schema='start_hack_2025'),
#  Table(name='ev3_dataprofile', share='start_hack_2025', schema='start_hack_2025')]

# %% [markdown]
# ### Table 1
# Energyvalve 3 dataprofile describing the datapoints found in the device data table.

# %%
df = spark.read.format("deltaSharing").load("config.share#start_hack_2025.start_hack_2025.ev3_dataprofile")
df.toPandas().sort_values(by=["unit"])
# Out:
#                  id access basetype  \
# 45  evcloudplus.461      r     real
# 18      evcloud.250     rw     real
# 3       evcloud.110      r     real
# 40  evcloudplus.382      r     real
# 41  evcloudplus.383      r     real
# 34  evcloudplus.359      r     real
# 39  evcloudplus.381      r     real
# 17      evcloud.240     rw     real
# 36  evcloudplus.360      r     real
# 46  evcloudplus.462      r     real
# 10      evcloud.180      r     real
# 11      evcloud.190      r     real
# 42  evcloudplus.384      r     real
# 52  evcloudplus.511      r     real
# 31  evcloudplus.261      r     real
# 30  evcloudplus.260      r     real
# 53  evcloudplus.512      r     real
# 54  evcloudplus.513      r     real
# 20      evcloud.252     rw     real
# 19      evcloud.251      r     real
# 43  evcloudplus.385      r     real
# 14      evcloud.210      r     real
# 13      evcloud.200      r     real
# 8       evcloud.160      r     real
# 7       evcloud.150      r     real
# 38   evcloudplus.37      r     real
# 44   evcloudplus.42      r     real
# 2       evcloud.100      r     real
# 33  evcloudplus.270      r     real
# 32  evcloudplus.269      r     real
# 26       evcloud.80      r     real
# 24       evcloud.60     rw     real
# 16      evcloud.230      r     real
# 5       evcloud.130      r     real
# 4       evcloud.120     rw     real
# 35   evcloudplus.36      r     real
# 27       evcloud.90     rw     real
# 25       evcloud.70      r     real
# 6       evcloud.140      r     real
# 0     evcloud.00009      r      int
# 1        evcloud.10      r      int
# 9       evcloud.170     rw      int
# 12       evcloud.20     rw      int
# 15      evcloud.220      r     real
# 21       evcloud.30     rw      int
# 22       evcloud.40     rw      int
# 23       evcloud.50     rw      int
# 28  evcloudplus.172      r     real
# 29  evcloudplus.173      r     real
# 37  evcloudplus.366      r      int
# 47  evcloudplus.463      r     real
# 48  evcloudplus.464      r     real
# 49  evcloudplus.465      r     real
# 50  evcloudplus.469      r     bool
# 51  evcloudplus.470      r     bool
# 55   evcloudplus.70      r      int
# 56   evcloudplus.85     rw      int
# 57   evcloudplus.88      r     real
# 58   evcloudplus.91      r     bool
#
#                                           description  \
# 45                               Flow_Volume_total_m3
# 18                   Setpoint Flow in m3/s at Delta T
# 3                               Absolute Flow in m3/s
# 40                       Flow_Volume_Heating_total_m3
# 41                       Flow_Volume_Cooling_total_m3
# 34                             dT_upper_deadbandLim_K
# 39                        last_copleted_month_average
# 17                              Setpoint Delta T in K
# 36                             dT_lower_deadBandLim_K
# 46                   moving_average_1h_1updated_value
# 10                       Applied Setpoint DeltaT in K
# 11                             Delta Temperature in K
# 42                             while_DDC_Sp_greater_0
# 52                             while_DDC_Sp_greater_0
# 31                                      Active_Time_h
# 30                                   Operating_Time_h
# 53                             while_DDC_Sp_greater_0
# 54                             while_DDC_Sp_greater_0
# 20                               Cloud Live Time in h
# 19                                Operating Time in h
# 43                             while_DDC_Sp_greater_0
# 14                                Heating Energy in J
# 13                                Cooling Energy in J
# 8                          Temperature 2 embeded in K
# 7                           Temperature 1 remote in K
# 38                                         DDC_Sp_Rel
# 44                                    V_Fb_Rel_2_Vnom
# 2                                  Relative Flow in %
# 33                           Start_And_Stop_Ratio_Rel
# 32                                    V_Sp_Rel_2_Vnom
# 26                             Relative Position in %
# 24                             Setpoint Relative in %
# 16                          Glycol concentration in %
# 5                                    Relative Power %
# 4                            Maximum Power Limit in %
# 35                                          RelPos_Sp
# 27                            Maximum Flow Limit in %
# 25  Setpoint Analog in Volt, only when Sp_Source=A...
# 6                                 Absolute Power in W
# 0                                          Valve Type
# 1                                    DN Size of Valve
# 9                             Delta T Limitation Type
# 12                                       Control Mode
# 15  Err_State_Cloud_(MSB=FreezeWarn|MP2_nAlive|Rev...
# 21                                   Override Control
# 22                              Installation Position
# 23                                    Setpoint Source
# 28               Upper_Control_Band_4_Flow_Rel_2_Vnom
# 29               Lower_Control_Band_4_Flow_Rel_2_Vnom
# 37             Sequence_(1=NoDmd|2=Cooling|3=Heating)
# 47           Amount_of_direction_changes_for_actuator
# 48  Amount_of_reaching_end_stops_at_0_and_100_percent
# 49  Actutor_cummulated_travel_distance_1_equal_100...
# 50                                       LoopSim_En_B
# 51                          Steady_State_in_Control_B
# 55  dT_Manager_Ste_(1=disabled|2=dT_selected_not_a...
# 56  DN_Selection (2=DN15, 3=DN20, 4=DN25, 5=DN32, ...
# 57  OpMode_Err_Override_included_(1=Position_Ctrl|...
# 58                           Vmin_En_(DDC_Sp=0->Vmin)
#
#                                                format  \
# 45                                               None
# 18                                               None
# 3                                                None
# 40                                               None
# 41                                               None
# 34                                               None
# 39                                               None
# 17                                               None
# 36                                               None
# 46                                               None
# 10                                               None
# 11                                               None
# 42                                               None
# 52                                               None
# 31                                               None
# 30                                               None
# 53                                               None
# 54                                               None
# 20                                               None
# 19                                               None
# 43                                               None
# 14                                               None
# 13                                               None
# 8                                                None
# 7                                                None
# 38                                               None
# 44                                               None
# 2                                                None
# 33                                               None
# 32                                               None
# 26                                               None
# 24                                               None
# 16                                               None
# 5                                                None
# 4                                                None
# 35                                               None
# 27                                               None
# 25                                               None
# 6                                                None
# 0                     application/vnd.belimo.enum;0|1
# 1                                                None
# 9                   application/vnd.belimo.enum;1|2|3
# 12                  application/vnd.belimo.enum;1|2|3
# 15                                               None
# 21     application/vnd.belimo.enum;1|2|3|4|5|6|7|8|11
# 22                    application/vnd.belimo.enum;1|2
# 23                    application/vnd.belimo.enum;1|2
# 28                                               None
# 29                                               None
# 37                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 55              application/vnd.belimo.enum;1|2|3|4|5
# 56  application/vnd.belimo.enum;2|3|4|5|6|7|8|9|10...
# 57                                               None
# 58                                               None
#
#                                       name  privacy  \
# 45                    Flow_Volume_total_m3    False
# 18                SpFlow_DeltaT_lmin_Write    False
# 3                           AbsFlow_Fb_m3s    False
# 40            Flow_Volume_Heating_total_m3    False
# 41            Flow_Volume_Cooling_total_m3    False
# 34                        dT_upper_dBLim_K    False
# 39                     dT_avg_last_month_K    False
# 17                        SpDeltaT_K_Write    False
# 36                        dT_lower_dBLim_K    False
# 46                   dT_movavg_1h1Update_K    False
# 10                      SpDeltaT_applied_K    False
# 11                                DeltaT_K    False
# 42               Active_dT_Manager_total_h    False
# 52            dT_Manager_TurnedOff_total_h    False
# 31                           Active_Time_h    False
# 30               Operating_Time_h_Research    False
# 53                             Full_Load_h    False
# 54                             Part_Load_h    False
# 20                          CloudLiveHours    False
# 19                          OperatingHours    False
# 43              Standby_dT_Manager_total_h    False
# 14                             Heating_E_J    False
# 13                             Cooling_E_J    False
# 8                             T2_embeded_K    False
# 7                              T1_remote_K    False
# 38                              DDC_Sp_Rel    False
# 44                         V_Fb_Rel_2_Vnom    False
# 2                      RelFlow_Fb_Rel2Vmax    False
# 33                Start_And_Stop_Ratio_Rel    False
# 32                         V_Sp_Rel_2_Vnom    False
# 26                               RelPos_Fb    False
# 24                        DDC_BUS_Sp_Write    False
# 16                Glycol_Concentration_Rel    False
# 5                     RelPower_Fb_Rel2Pmax    False
# 4                           Pmax_Rel_Write    False
# 35                               RelPos_Sp    False
# 27                          Vmax_Rel_Write    False
# 25                                DDC_Sp_V    False
# 6                            AbsPower_Fb_W    False
# 0                                ValveType    False
# 1                                  DN_Size    False
# 9                  DeltaT_Limitation_Write    False
# 12                       ControlMode_Write    False
# 15                      Error_Status_Cloud    False
# 21                          Override_Write    False
# 22              InstallationPosition_Write    False
# 23                          SpSource_Write    False
# 28               Upper_Control_Band_4_Flow    False
# 29               Lower_Control_Band_4_Flow    False
# 37                            Sequence_Ste    False
# 47                    Act_Dir_Chngs_Counts    False
# 48                      Act_End_Hit_Counts    False
# 49               Act_total_travel_fraction    False
# 50                            LoopSim_En_B    False
# 51                          Steady_State_B    False
# 55                          dT_Manager_Ste    False
# 56                      DN_Selection_Write    False
# 57  OpMode_Err_Override_included_raw_value    False
# 58                      Vmin_Ctrl_En_Write    False
#
#                    restriction        definedBy                 unit
# 45  [-2147483.648,2147483.647]  evcloudplus/1.2           cubicMetre
# 18                     [0,0.1]      evcloud/1.2  cubicMetrePerSecond
# 3   [-2147483.648,2147483.647]      evcloud/1.2  cubicMetrePerSecond
# 40  [-2147483.648,2147483.647]  evcloudplus/1.2  cubicMetrePerSecond
# 41  [-2147483.648,2147483.647]  evcloudplus/1.2  cubicMetrePerSecond
# 34  [-2147483.648,2147483.647]  evcloudplus/1.2   differentialKelvin
# 39  [-2147483.648,2147483.647]  evcloudplus/1.2   differentialKelvin
# 17                  [1,55.556]      evcloud/1.2   differentialKelvin
# 36  [-2147483.648,2147483.647]  evcloudplus/1.2   differentialKelvin
# 46  [-2147483.648,2147483.647]  evcloudplus/1.2   differentialKelvin
# 10  [-2147483.648,2147483.647]      evcloud/1.2   differentialKelvin
# 11  [-2147483.648,2147483.647]      evcloud/1.2   differentialKelvin
# 42  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 52  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 31  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 30  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 53  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 54  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 20  [-2147483.648,2147483.647]      evcloud/1.2                 hour
# 19  [-2147483.648,2147483.647]      evcloud/1.2                 hour
# 43  [-2147483.648,2147483.647]  evcloudplus/1.2                 hour
# 14  [-2147483.648,2147483.647]      evcloud/1.2                joule
# 13  [-2147483.648,2147483.647]      evcloud/1.2                joule
# 8   [-2147483.648,2147483.647]      evcloud/1.2               kelvin
# 7   [-2147483.648,2147483.647]      evcloud/1.2               kelvin
# 38  [-2147483.648,2147483.647]  evcloudplus/1.2              percent
# 44  [-2147483.648,2147483.647]  evcloudplus/1.2              percent
# 2   [-2147483.648,2147483.647]      evcloud/1.2              percent
# 33  [-2147483.648,2147483.647]  evcloudplus/1.2              percent
# 32  [-2147483.648,2147483.647]  evcloudplus/1.2              percent
# 26  [-2147483.648,2147483.647]      evcloud/1.2              percent
# 24                     [0,100]      evcloud/1.2              percent
# 16  [-2147483.648,2147483.647]      evcloud/1.2              percent
# 5   [-2147483.648,2147483.647]      evcloud/1.2              percent
# 4                    [0.5,100]      evcloud/1.2              percent
# 35  [-2147483.648,2147483.647]  evcloudplus/1.2              percent
# 27                    [30,100]      evcloud/1.2              percent
# 25  [-2147483.648,2147483.647]      evcloud/1.2                 volt
# 6   [-2147483.648,2147483.647]      evcloud/1.2                 watt
# 0                        uint8      evcloud/1.2                 None
# 1                        int32      evcloud/1.2                 None
# 9                        uint8      evcloud/1.2                 None
# 12                       int32      evcloud/1.2                 None
# 15  [-2147483.648,2147483.647]      evcloud/1.2                 None
# 21                       int32      evcloud/1.2                 None
# 22                       uint8      evcloud/1.2                 None
# 23                       int32      evcloud/1.2                 None
# 28  [-2147483.648,2147483.647]  evcloudplus/1.2                 None
# 29  [-2147483.648,2147483.647]  evcloudplus/1.2                 None
# 37                       int32  evcloudplus/1.2                 None
# 47  [-2147483.648,2147483.647]  evcloudplus/1.2                 None
# 48  [-2147483.648,2147483.647]  evcloudplus/1.2                 None
# 49  [-2147483.648,2147483.647]  evcloudplus/1.2                 None
# 50                        None  evcloudplus/1.2                 None
# 51                        None  evcloudplus/1.2                 None
# 55                       int32  evcloudplus/1.2                 None
# 56                       uint8  evcloudplus/1.2                 None
# 57  [-2147483.648,2147483.647]  evcloudplus/1.2                 None
# 58                        None  evcloudplus/1.2                 None

# %% [markdown]
# ### Table 2
# Energyvalve 3 device data. **Big data** list of timeseries samples for devices. Devices are differentiated by the **device_id** column.

# %%
df = spark.read.format("deltaSharing").load("config.share#start_hack_2025.start_hack_2025.ev3_device_data").filter(device_id="14e5bc06-9e32-4938-96df-82a070581e7d").limit(3)
a = df.toPandas()
a
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = spark.read.format("deltaSharing").load("config.share#start_hack_2025.start_hack_2025.ev3_device_data").select("14e5bc06-9e32-4938-96df-82a070581e7d	").limit(3)
#       2 a = df.toPandas()
#       3 a
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:3229, in DataFrame.select(self, *cols)
#    3184 def select(self, *cols: "ColumnOrName") -> "DataFrame":  # type: ignore[misc]
#    3185     """Projects a set of expressions and returns a new :class:`DataFrame`.
#    3186
#    3187     .. versionadded:: 1.3.0
#    (...)
#    3227     +-----+---+
#    3228     """
# -> 3229     jdf = self._jdf.select(self._jcols(*cols))
#    3230     return DataFrame(jdf, self.sparkSession)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `14e5bc06-9e32-4938-96df-82a070581e7d	` cannot be resolved. Did you mean one of the following? [`T2_embeded_K`, `device_id`, `Active_dT_Manager_total_h`, `Glycol_Concentration_Rel`, `Override_Write`].;
# 'Project ['14e5bc06-9e32-4938-96df-82a070581e7d	]
# +- Relation [device_id#6048,dataprofile_id#6049,cloud_received_time#6050,sample_time#6051,year#6052,year_month#6053,year_month_day#6054,influx_migration_source_filename#6055,T1_remote_K#6056,T2_embeded_K#6057,RelFlow_Fb_Rel2Vmax#6058,RelPower_Fb_Rel2Pmax#6059,AbsFlow_Fb_m3s#6060,AbsPower_Fb_W#6061,Heating_E_J#6062,Glycol_Concentration_Rel#6063,ControlMode_Write#6064,Cooling_E_J#6065,RelPos_Fb#6066,DeltaT_Limitation_Write#6067,SpDeltaT_K_Write#6068,Pmax_Rel_Write#6069,Vmax_Rel_Write#6070,InstallationPosition_Write#6071,... 14 more fields] parquet

# %%
a["DeltaT_K"].to_numpy()
# Out:
# array([26.49960869, 26.5049261 , 26.6936532 ])

# %% [markdown]
# ### Plot
# Heat Exchanger Characteristic

# %%
from pyspark.sql.functions import col
import matplotlib.pyplot as plt

device_id = "1a9da8fa-6fa8-49f3-8aaa-420b34eefe57"
year_month = "202103"
x = "AbsFlow_Fb_m3s"
y = "AbsPower_Fb_W"
df_data = spark.read.format("deltaSharing").load("config.share#start_hack_2025.start_hack_2025.ev3_device_data").filter((col("device_id") == device_id) & (col("year_month") == year_month)).toPandas()
year_month = year_month[:4] + '-' + year_month[4:]
plt.scatter(df_data[x], df_data[y])
plt.xlabel(x)
plt.ylabel(y)
plt.title(f"Heat Exchanger Measurments ({year_month}) \n Device ID: {device_id}")
plt.show()

# %% [markdown]
# ### Table 3
# Cloud api logs describing interactions with our cloud.

# %%
df = spark.read.format("deltaSharing").load("config.share#start_hack_2025.start_hack_2025.cc_api_logs").limit(3)
df.columns
# Out:
# ['api',
#  'class',
#  'cloudEnv',
#  'component',
#  'correlationId',
#  'developmentDevice',
#  'durationInMs',
#  'host',
#  'httpStatus',
#  'logEnv',
#  'method',
#  'principal',
#  'requestId',
#  'requestURI',
#  'requestURL',
#  'signature',
#  'signatureFull',
#  'signatureId',
#  'threadName',
#  'userAgent',
#  'timestamp']
